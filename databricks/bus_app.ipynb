# %%
# !pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in c:\programdata\anaconda3\envs\spark_bus_env01\lib\site-packages (2.0.2)

# %%
from kafka import KafkaProducer
from kafka import KafkaConsumer 
from json import dumps
import json
import pandas as pd
import time
import datetime
import threading

# %%
#버스 위치 정보가 저장된 파일 읽기
location_df = pd.read_csv("location.csv")

# %%
#위치 정보 조회
location_df
# Out:
#            id        date   route_id    vh_id route_nm  now_latitude  \
# 0      210457  2019-10-29  405136001  7997025    360-1     33.457724
# 1      210458  2019-10-29  405136001  7997025    360-1     33.458783
# 2      210459  2019-10-29  405136001  7997025    360-1     33.478867
# 3      210460  2019-10-29  405136001  7997025    360-1     33.478850
# 4      210461  2019-10-29  405136001  7997025    360-1     33.480700
# ...       ...         ...        ...      ...      ...           ...
# 91769  302350  2019-11-05  405328102  7983486    281-2     33.493625
# 91770  302351  2019-11-05  405328102  7983486    281-2     33.495540
# 91771  302352  2019-11-05  405328102  7983486    281-2     33.498925
# 91772  302353  2019-11-05  405328102  7983486    281-2     33.500473
# 91773  302354  2019-11-05  405328102  7983486    281-2     33.499916
#
#        now_longitude   now_station now_arrive_time  distance next_station  \
# 0         126.554014          제대마을             07시     333.0        제대아파트
# 1         126.557353         제대아파트             07시     415.0        제주대학교
# 2         126.483833   한라중학교/부영아파트             08시     417.0      대림2차아파트
# 3         126.488350       대림2차아파트             08시     334.0    연동대림1차아파트
# 4         126.489933     연동대림1차아파트             08시     550.0        케이티앤지
# ...              ...           ...             ...       ...          ...
# 91769     126.534764  제주지방법원(광양방면)             20시     272.0   고산동산(광양방면)
# 91770     126.532907    고산동산(광양방면)             20시     447.0   제주시청(광양방면)
# 91771     126.530351    제주시청(광양방면)             20시     418.0        광양사거리
# 91772     126.527103         광양사거리             20시     140.0  탐라장애인 종합복지관
# 91773     126.521348          용천마을             20시     541.0  제주버스터미널(종점)
#
#        next_latitude  next_longitude
# 0          33.458783      126.557353
# 1          33.459893      126.561624
# 2          33.478850      126.488350
# 3          33.480700      126.489933
# 4          33.482077      126.485355
# ...              ...             ...
# 91769      33.495540      126.532907
# 91770      33.498925      126.530351
# 91771      33.500473      126.527103
# 91772      33.500228      126.525625
# 91773      33.499190      126.516324
#
# [91774 rows x 13 columns]

# %%
#0 번째 위치 정보 조회
location_df.loc[0]
# Out:
# id                     210457
# date               2019-10-29
# route_id            405136001
# vh_id                 7997025
# route_nm                360-1
# now_latitude        33.457724
# now_longitude      126.554014
# now_station              제대마을
# now_arrive_time           07시
# distance                333.0
# next_station            제대아파트
# next_latitude       33.458783
# next_longitude     126.557353
# Name: 0, dtype: object

# %%
# location_df.loc[0] : 0 번째 위치 정보 조회
# to_json() : 0번째 위치 정보를 JSON 으로 변환
# force_ascii=False : ascii 형태로 변환 하지 않음
location_df.loc[0].to_json(force_ascii=False)
# Out:
# '{"id":210457,"date":"2019-10-29","route_id":405136001,"vh_id":7997025,"route_nm":"360-1","now_latitude":33.457724,"now_longitude":126.554014,"now_station":"제대마을","now_arrive_time":"07시","distance":333.0,"next_station":"제대아파트","next_latitude":33.458783,"next_longitude":126.557353}'

# %%
#Kafka로 버스 현재 위치를 전송하는객체
bus_producer=KafkaProducer(
            #메시지 받은 사람이 메시지를 잘 받았는지 체크하는 옵션 
            #(0은 그냥 보내기만 한다. 확인x)
            acks=0, 
            #메시지 전달할 때 압축
            compression_type='gzip', 
            #현재 위치를 저장할 카프카 아이피
            bootstrap_servers=['192.168.56.101:9092'], 
            #직렬화 : 데이터 전송을 위해 byte단위로 바꿔주는 작업 : 
            #dumps 함수이용. dump : json 값을 메모리에 올려준다.
            #encode를 통해서 올린다.x가 있으면, x를 dumps로 바꾸고
            #utf-8 로 설정한다
            value_serializer=lambda x: dumps(x).encode('utf-8') 
          )

# %%
#인공지능 서버에서 버스 도착예측 시간을 가져오는 객체
bus_consumer=KafkaConsumer( 
                        #읽어올 토픽의 이름  
                        "car_arrive_topic",
                        # 카프카 서버 아이피:포트
                          bootstrap_servers=['192.168.56.101:9092'], 
                        # 어디서부터 값을 읽어올지 설정 (earlest 가장 처음 latest는 가장 최근)
                        auto_offset_reset="latest",
                        # 완료되었을 떄 문자 전송
                        enable_auto_commit=True, 
                        # 그룹핑하여 토픽 지정할 수 있다 > 같은 컨슈머로 작업
                        group_id='my-group', 
                        # 역직렬화 ( 받을 떄 ) ; 메모리에서 읽어오므로 loads라는 함수를 이용한다. // 직렬화 (보낼 떄)
                        value_deserializer=lambda x: json.loads(x.decode('utf-8')),
                        # 10000000 밀리초 이후에 메시지가 오지 않으면 없는 것으로 취급.
                        consumer_timeout_ms=10000000
            )

# %%
#len(location_df) : 버스 도착정보의 개수
#버스 도착 정보의 개수를 location_count에 저장
location_count = len(location_df)
location_count
# Out:
# 91774

# %%
#버스 위치 정보를 인공지능 서버로 전송하는 함수
def send_location() :
    #전송할 데이터의 인덱스
    index = 0
    
    while True:
        # location_count : 버스 도착정보의 개수
        # index : 전송할 데이터의 인덱스
        # 전송할 데이터의 개수가 버스 도착정보 개수 이상
        if index >= location_count :
            #인덱스 초기화
            index = 0
        #datetime.datetime.now() : 현재 시간 리턴    
        now = datetime.datetime.now()
        #location_df.loc[index] : index 번째 위치정보를 리턴
        location_row = location_df.loc[index]
        # location_row :index 번째 위치 정보
        # to_json() : 0번째 위치 정보를 JSON 으로 변환
        # force_ascii=False : ascii 형태로 변환 하지 않음
        data = location_row.to_json(force_ascii=False)
        #data를 JSON 형태 객체로 변환
        data = json.loads(data)
        # now.hour : 현재 시간을 리턴
        #현재 시간(now.hour)를 data에 hour 로 저장
        data["hour"] = now.hour
        #now.weekday() : 현재 요일 
        #현재 요일(now.weekday())를 data에 weekday 로 저장
        data["weekday"] = now.weekday()
        #car_location_topic으로 data 를 전송할 준비
        bus_producer.send('car_location_topic',value=data)
        #Kafka로 데이터 전송
        bus_producer.flush()
        #전송한 데이터 출력
        print("send location data =", data)
        #30초 대기
        time.sleep(30)
        #index 1증가
        index = index + 1
        print("=" * 100)

# %%
#인공지능 서버에서 도착 예정 시간을 출력하는 함수
def get_arrive():

    #bus_consumer : 인공지능 서버에서 전송한 
    #               버스 도착 예정 시간을 가져오는 객체
    
    # 가져온 버스 도착 예정 시간은 arrive에 저장
    for arrive in bus_consumer:
        print("get_arrive : arrive =",arrive)
        print("=" * 100)

# %%
#send_location 버스 현재 위치를 인공지능 서버로 전송 함수
#threading.Thread: send_location 함수를 멀티 쓰레드로 실행 할 객체
t1 = threading.Thread(target=send_location)
#get_arrive : 인공지능 서버의 도착 시간을 가져오는 함수
#threading.Thread: get_arrive 함수를 멀티 쓰레드로 실행 할 객체
t2 = threading.Thread(target=get_arrive)
#멀티 쓰레드 시작
t2.start()
#멀티 쓰레드 시작
t1.start()
#멀티 쓰레드 종료 할때까지 대기
t2.join()
t1.join()
# Out:
# send location data = {'id': 210457, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.457724, 'now_longitude': 126.554014, 'now_station': '제대마을', 'now_arrive_time': '07시', 'distance': 333.0, 'next_station': '제대아파트', 'next_latitude': 33.458783, 'next_longitude': 126.557353, 'hour': 16, 'weekday': 4}
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=24, timestamp=1688106152896, timestamp_type=0, key=None, value={'id': 210577, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.485662, 'now_longitude': 126.494923, 'now_station': '도호동', 'now_arrive_time': '18시', 'distance': 321.0, 'next_station': '연동주민센터', 'next_latitude': 33.487317, 'next_longitude': 126.496617, 'hour': 14, 'weekday': 4, 'arrive_time': 89.01767764039674}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=415, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=25, timestamp=1688106183649, timestamp_type=0, key=None, value={'id': 210578, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.487317, 'now_longitude': 126.496617, 'now_station': '연동주민센터', 'now_arrive_time': '18시', 'distance': 455.0, 'next_station': '제주도청 신제주로터리', 'next_latitude': 33.491433, 'next_longitude': 126.496783, 'hour': 14, 'weekday': 4, 'arrive_time': 100.81839376899568}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=459, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=26, timestamp=1688106214409, timestamp_type=0, key=None, value={'id': 210579, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.491433, 'now_longitude': 126.496783, 'now_station': '제주도청 신제주로터리', 'now_arrive_time': '18시', 'distance': 528.0, 'next_station': '연동입구', 'next_latitude': 33.496203, 'next_longitude': 126.496995, 'hour': 14, 'weekday': 4, 'arrive_time': 109.20998381343948}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=447, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=27, timestamp=1688106245261, timestamp_type=0, key=None, value={'id': 210580, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.496203, 'now_longitude': 126.496995, 'now_station': '연동입구', 'now_arrive_time': '18시', 'distance': 753.0, 'next_station': '오라3동', 'next_latitude': 33.49925, 'next_longitude': 126.503183, 'hour': 14, 'weekday': 4, 'arrive_time': 108.66913628125454}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=404, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=28, timestamp=1688106275984, timestamp_type=0, key=None, value={'id': 210581, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.49925, 'now_longitude': 126.503183, 'now_station': '오라3동', 'now_arrive_time': '18시', 'distance': 381.0, 'next_station': '월구마을', 'next_latitude': 33.500133, 'next_longitude': 126.507, 'hour': 14, 'weekday': 4, 'arrive_time': 79.65173025822743}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=400, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=29, timestamp=1688106306811, timestamp_type=0, key=None, value={'id': 210582, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.500133, 'now_longitude': 126.507, 'now_station': '월구마을', 'now_arrive_time': '18시', 'distance': 375.0, 'next_station': '동성마을', 'next_latitude': 33.500045, 'next_longitude': 126.511035, 'hour': 14, 'weekday': 4, 'arrive_time': 79.17615098876867}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=406, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=30, timestamp=1688106337558, timestamp_type=0, key=None, value={'id': 210583, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.500045, 'now_longitude': 126.511035, 'now_station': '동성마을', 'now_arrive_time': '18시', 'distance': 354.0, 'next_station': '제주버스터미널', 'next_latitude': 33.49993, 'next_longitude': 126.514863, 'hour': 14, 'weekday': 4, 'arrive_time': 79.53653994519792}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=426, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=31, timestamp=1688106368307, timestamp_type=0, key=None, value={'id': 210584, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.49993, 'now_longitude': 126.514863, 'now_station': '제주버스터미널', 'now_arrive_time': '18시', 'distance': 262.0, 'next_station': '한국병원', 'next_latitude': 33.499793, 'next_longitude': 126.517687, 'hour': 14, 'weekday': 4, 'arrive_time': 79.02376573291988}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=426, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=32, timestamp=1688106399067, timestamp_type=0, key=None, value={'id': 210585, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.499789, 'now_longitude': 126.523759, 'now_station': '남서광마을', 'now_arrive_time': '18시', 'distance': 193.0, 'next_station': '탐라장애인 종합복지관', 'next_latitude': 33.500017, 'next_longitude': 126.525833, 'hour': 14, 'weekday': 4, 'arrive_time': 45.38809863206166}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=452, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=33, timestamp=1688106429806, timestamp_type=0, key=None, value={'id': 210586, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.500017, 'now_longitude': 126.525833, 'now_station': '탐라장애인 종합복지관', 'now_arrive_time': '18시', 'distance': 459.0, 'next_station': '제주시청(아라방면)', 'next_latitude': 33.49956, 'next_longitude': 126.529771, 'hour': 14, 'weekday': 4, 'arrive_time': 99.07887568744064}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=471, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=34, timestamp=1688106460720, timestamp_type=0, key=None, value={'id': 210587, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.493109, 'now_longitude': 126.535091, 'now_station': '제주지방법원(아라방면)', 'now_arrive_time': '19시', 'distance': 525.0, 'next_station': '제주중앙여자고등학교(아라방면)', 'next_latitude': 33.489414, 'next_longitude': 126.538642, 'hour': 14, 'weekday': 4, 'arrive_time': 118.75828775338745}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=510, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=35, timestamp=1688106491513, timestamp_type=0, key=None, value={'id': 210588, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.489414, 'now_longitude': 126.538642, 'now_station': '제주중앙여자고등학교(아라방면)', 'now_arrive_time': '19시', 'distance': 642.0, 'next_station': '제주여자중고등학교(아라방면)', 'next_latitude': 33.48486, 'next_longitude': 126.542928, 'hour': 14, 'weekday': 4, 'arrive_time': 88.36504462788032}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=526, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=36, timestamp=1688106522478, timestamp_type=0, key=None, value={'id': 210589, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.48486, 'now_longitude': 126.542928, 'now_station': '제주여자중고등학교(아라방면)', 'now_arrive_time': '19시', 'distance': 578.0, 'next_station': '남국원(아라방면)', 'next_latitude': 33.479705, 'next_longitude': 126.543811, 'hour': 14, 'weekday': 4, 'arrive_time': 87.17106216941892}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=484, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=37, timestamp=1688106553367, timestamp_type=0, key=None, value={'id': 210590, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.479705, 'now_longitude': 126.543811, 'now_station': '남국원(아라방면)', 'now_arrive_time': '19시', 'distance': 355.0, 'next_station': '아라초등학교', 'next_latitude': 33.476533, 'next_longitude': 126.544283, 'hour': 14, 'weekday': 4, 'arrive_time': 71.7017196265301}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=440, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=38, timestamp=1688106584042, timestamp_type=0, key=None, value={'id': 210591, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.476533, 'now_longitude': 126.544283, 'now_station': '아라초등학교', 'now_arrive_time': '19시', 'distance': 350.0, 'next_station': '아라주공아파트', 'next_latitude': 33.473655, 'next_longitude': 126.545425, 'hour': 14, 'weekday': 4, 'arrive_time': 73.71861499575672}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=439, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=39, timestamp=1688106615118, timestamp_type=0, key=None, value={'id': 210592, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.473655, 'now_longitude': 126.545425, 'now_station': '아라주공아파트', 'now_arrive_time': '19시', 'distance': 244.0, 'next_station': '인다마을', 'next_latitude': 33.47145, 'next_longitude': 126.5454, 'hour': 14, 'weekday': 4, 'arrive_time': 59.66085835032971}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=424, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=40, timestamp=1688106645945, timestamp_type=0, key=None, value={'id': 210593, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.47145, 'now_longitude': 126.5454, 'now_station': '인다마을', 'now_arrive_time': '19시', 'distance': 330.0, 'next_station': '제주대학교병원', 'next_latitude': 33.469089, 'next_longitude': 126.547389, 'hour': 14, 'weekday': 4, 'arrive_time': 63.66209904154153}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=424, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=41, timestamp=1688106676875, timestamp_type=0, key=None, value={'id': 210594, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.469089, 'now_longitude': 126.547389, 'now_station': '제주대학교병원', 'now_arrive_time': '19시', 'distance': 738.0, 'next_station': '죽성마을 입구', 'next_latitude': 33.46313, 'next_longitude': 126.549102, 'hour': 14, 'weekday': 4, 'arrive_time': 76.54394685157837}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=439, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=42, timestamp=1688106707724, timestamp_type=0, key=None, value={'id': 210595, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.456267, 'now_longitude': 126.55175, 'now_station': '제주대학교입구', 'now_arrive_time': '19시', 'distance': 266.0, 'next_station': '제대마을', 'next_latitude': 33.457724, 'next_longitude': 126.554014, 'hour': 14, 'weekday': 4, 'arrive_time': 40.385749410882326}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=427, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=43, timestamp=1688106738520, timestamp_type=0, key=None, value={'id': 210596, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.457724, 'now_longitude': 126.554014, 'now_station': '제대마을', 'now_arrive_time': '19시', 'distance': 333.0, 'next_station': '제대아파트', 'next_latitude': 33.458783, 'next_longitude': 126.557353, 'hour': 14, 'weekday': 4, 'arrive_time': 46.80134154928938}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=415, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=44, timestamp=1688106769278, timestamp_type=0, key=None, value={'id': 210597, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.458783, 'now_longitude': 126.557353, 'now_station': '제대아파트', 'now_arrive_time': '19시', 'distance': 415.0, 'next_station': '제주대학교', 'next_latitude': 33.459893, 'next_longitude': 126.561624, 'hour': 14, 'weekday': 4, 'arrive_time': 50.022216651606}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=419, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=45, timestamp=1688106800376, timestamp_type=0, key=None, value={'id': 210598, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.479705, 'now_longitude': 126.543811, 'now_station': '남국원(아라방면)', 'now_arrive_time': '20시', 'distance': 578.0, 'next_station': '제주여자중고등학교(아라방면)', 'next_latitude': 33.48486, 'next_longitude': 126.542928, 'hour': 14, 'weekday': 4, 'arrive_time': 75.88423651711244}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=484, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=46, timestamp=1688106831028, timestamp_type=0, key=None, value={'id': 210599, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.48486, 'now_longitude': 126.542928, 'now_station': '제주여자중고등학교(아라방면)', 'now_arrive_time': '20시', 'distance': 642.0, 'next_station': '제주중앙여자고등학교(아라방면)', 'next_latitude': 33.489414, 'next_longitude': 126.538642, 'hour': 14, 'weekday': 4, 'arrive_time': 117.15643477224096}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=527, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=47, timestamp=1688106862193, timestamp_type=0, key=None, value={'id': 210600, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.496007, 'now_longitude': 126.532287, 'now_station': '고산동산(아라방면)', 'now_arrive_time': '20시', 'distance': 454.0, 'next_station': '제주시청(아라방면)', 'next_latitude': 33.49956, 'next_longitude': 126.529771, 'hour': 14, 'weekday': 4, 'arrive_time': 99.50184472738835}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=460, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=48, timestamp=1688106892885, timestamp_type=0, key=None, value={'id': 210601, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.478867, 'now_longitude': 126.483833, 'now_station': '한라중학교/부영아파트', 'now_arrive_time': '21시', 'distance': 417.0, 'next_station': '대림2차아파트', 'next_latitude': 33.47885, 'next_longitude': 126.48835, 'hour': 14, 'weekday': 4, 'arrive_time': 113.77325495259835}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=458, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=49, timestamp=1688106923709, timestamp_type=0, key=None, value={'id': 210602, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.47885, 'now_longitude': 126.48835, 'now_station': '대림2차아파트', 'now_arrive_time': '21시', 'distance': 334.0, 'next_station': '연동대림1차아파트', 'next_latitude': 33.4807, 'next_longitude': 126.489933, 'hour': 14, 'weekday': 4, 'arrive_time': 72.68373623136941}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=443, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=50, timestamp=1688106954688, timestamp_type=0, key=None, value={'id': 210603, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.4807, 'now_longitude': 126.489933, 'now_station': '연동대림1차아파트', 'now_arrive_time': '21시', 'distance': 550.0, 'next_station': '케이티앤지', 'next_latitude': 33.482077, 'next_longitude': 126.485355, 'hour': 14, 'weekday': 4, 'arrive_time': 125.83819610752325}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=439, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=51, timestamp=1688106985447, timestamp_type=0, key=None, value={'id': 210604, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.482077, 'now_longitude': 126.485355, 'now_station': '케이티앤지', 'now_arrive_time': '21시', 'distance': 199.0, 'next_station': '롯데마트', 'next_latitude': 33.482142, 'next_longitude': 126.483213, 'hour': 14, 'weekday': 4, 'arrive_time': 49.69137610729037}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=415, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=52, timestamp=1688107016198, timestamp_type=0, key=None, value={'id': 210605, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.482142, 'now_longitude': 126.483213, 'now_station': '롯데마트', 'now_arrive_time': '21시', 'distance': 341.0, 'next_station': '원노형', 'next_latitude': 33.483446, 'next_longitude': 126.480758, 'hour': 14, 'weekday': 4, 'arrive_time': 72.73916709665347}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=403, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=53, timestamp=1688107046825, timestamp_type=0, key=None, value={'id': 210606, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.483446, 'now_longitude': 126.480758, 'now_station': '원노형', 'now_arrive_time': '21시', 'distance': 185.0, 'next_station': '노형오거리', 'next_latitude': 33.4858535, 'next_longitude': 126.48053, 'hour': 14, 'weekday': 4, 'arrive_time': 87.50300666570378}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=409, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=54, timestamp=1688107077751, timestamp_type=0, key=None, value={'id': 210607, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.488046, 'now_longitude': 126.483112, 'now_station': '남녕고등학교', 'now_arrive_time': '21시', 'distance': 322.0, 'next_station': '한라병원', 'next_latitude': 33.489633, 'next_longitude': 126.486, 'hour': 14, 'weekday': 4, 'arrive_time': 90.61380442407045}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=418, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=55, timestamp=1688107108317, timestamp_type=0, key=None, value={'id': 210608, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.489633, 'now_longitude': 126.486, 'now_station': '한라병원', 'now_arrive_time': '21시', 'distance': 291.0, 'next_station': '삼무공원사거리', 'next_latitude': 33.4899, 'next_longitude': 126.488917, 'hour': 14, 'weekday': 4, 'arrive_time': 90.32873026098733}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=422, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=56, timestamp=1688107139179, timestamp_type=0, key=None, value={'id': 210609, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.4899, 'now_longitude': 126.488917, 'now_station': '삼무공원사거리', 'now_arrive_time': '21시', 'distance': 381.0, 'next_station': '제원아파트', 'next_latitude': 33.487531, 'next_longitude': 126.489892, 'hour': 14, 'weekday': 4, 'arrive_time': 90.99605324190271}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=431, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=57, timestamp=1688107169899, timestamp_type=0, key=None, value={'id': 210610, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.487531, 'now_longitude': 126.489892, 'now_station': '제원아파트', 'now_arrive_time': '21시', 'distance': 267.0, 'next_station': '은남동', 'next_latitude': 33.485822, 'next_longitude': 126.490897, 'hour': 15, 'weekday': 4, 'arrive_time': 85.63756908573406}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=409, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=58, timestamp=1688107200712, timestamp_type=0, key=None, value={'id': 210611, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.485822, 'now_longitude': 126.490897, 'now_station': '은남동', 'now_arrive_time': '21시', 'distance': 374.0, 'next_station': '도호동', 'next_latitude': 33.485662, 'next_longitude': 126.494923, 'hour': 15, 'weekday': 4, 'arrive_time': 80.6899375580568}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=396, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=59, timestamp=1688107231460, timestamp_type=0, key=None, value={'id': 210612, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.485662, 'now_longitude': 126.494923, 'now_station': '도호동', 'now_arrive_time': '21시', 'distance': 321.0, 'next_station': '연동주민센터', 'next_latitude': 33.487317, 'next_longitude': 126.496617, 'hour': 15, 'weekday': 4, 'arrive_time': 89.11363050673977}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=415, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=60, timestamp=1688107262055, timestamp_type=0, key=None, value={'id': 210613, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.487317, 'now_longitude': 126.496617, 'now_station': '연동주민센터', 'now_arrive_time': '22시', 'distance': 455.0, 'next_station': '제주도청 신제주로터리', 'next_latitude': 33.491433, 'next_longitude': 126.496783, 'hour': 15, 'weekday': 4, 'arrive_time': 100.81839376899568}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=459, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=61, timestamp=1688107292685, timestamp_type=0, key=None, value={'id': 210614, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.49993, 'now_longitude': 126.514863, 'now_station': '제주버스터미널', 'now_arrive_time': '22시', 'distance': 262.0, 'next_station': '한국병원', 'next_latitude': 33.499793, 'next_longitude': 126.517687, 'hour': 15, 'weekday': 4, 'arrive_time': 79.02376573291988}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=426, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=62, timestamp=1688107323469, timestamp_type=0, key=None, value={'id': 210615, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.499789, 'now_longitude': 126.523759, 'now_station': '남서광마을', 'now_arrive_time': '22시', 'distance': 193.0, 'next_station': '탐라장애인 종합복지관', 'next_latitude': 33.500017, 'next_longitude': 126.525833, 'hour': 15, 'weekday': 4, 'arrive_time': 45.38809863206166}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=452, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=63, timestamp=1688107354277, timestamp_type=0, key=None, value={'id': 210616, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.500017, 'now_longitude': 126.525833, 'now_station': '탐라장애인 종합복지관', 'now_arrive_time': '22시', 'distance': 459.0, 'next_station': '제주시청(아라방면)', 'next_latitude': 33.49956, 'next_longitude': 126.529771, 'hour': 15, 'weekday': 4, 'arrive_time': 99.07887568744064}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=471, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=64, timestamp=1688107384849, timestamp_type=0, key=None, value={'id': 210617, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.49956, 'now_longitude': 126.529771, 'now_station': '제주시청(아라방면)', 'now_arrive_time': '22시', 'distance': 454.0, 'next_station': '고산동산(아라방면)', 'next_latitude': 33.496007, 'next_longitude': 126.532287, 'hour': 15, 'weekday': 4, 'arrive_time': 99.29426313416039}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=460, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=65, timestamp=1688107415602, timestamp_type=0, key=None, value={'id': 210618, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.489414, 'now_longitude': 126.538642, 'now_station': '제주중앙여자고등학교(아라방면)', 'now_arrive_time': '22시', 'distance': 642.0, 'next_station': '제주여자중고등학교(아라방면)', 'next_latitude': 33.48486, 'next_longitude': 126.542928, 'hour': 15, 'weekday': 4, 'arrive_time': 88.36504462788032}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=526, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=66, timestamp=1688107446516, timestamp_type=0, key=None, value={'id': 210619, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.48486, 'now_longitude': 126.542928, 'now_station': '제주여자중고등학교(아라방면)', 'now_arrive_time': '22시', 'distance': 578.0, 'next_station': '남국원(아라방면)', 'next_latitude': 33.479705, 'next_longitude': 126.543811, 'hour': 15, 'weekday': 4, 'arrive_time': 87.17106216941892}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=484, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=67, timestamp=1688107477163, timestamp_type=0, key=None, value={'id': 210620, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.479705, 'now_longitude': 126.543811, 'now_station': '남국원(아라방면)', 'now_arrive_time': '22시', 'distance': 355.0, 'next_station': '아라초등학교', 'next_latitude': 33.476533, 'next_longitude': 126.544283, 'hour': 15, 'weekday': 4, 'arrive_time': 71.7017196265301}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=440, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=68, timestamp=1688107507831, timestamp_type=0, key=None, value={'id': 210621, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.476533, 'now_longitude': 126.544283, 'now_station': '아라초등학교', 'now_arrive_time': '22시', 'distance': 350.0, 'next_station': '아라주공아파트', 'next_latitude': 33.473655, 'next_longitude': 126.545425, 'hour': 15, 'weekday': 4, 'arrive_time': 73.71861499575672}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=439, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=69, timestamp=1688107538590, timestamp_type=0, key=None, value={'id': 210622, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.473655, 'now_longitude': 126.545425, 'now_station': '아라주공아파트', 'now_arrive_time': '22시', 'distance': 244.0, 'next_station': '인다마을', 'next_latitude': 33.47145, 'next_longitude': 126.5454, 'hour': 15, 'weekday': 4, 'arrive_time': 59.66085835032971}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=424, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=70, timestamp=1688107569625, timestamp_type=0, key=None, value={'id': 210623, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.47145, 'now_longitude': 126.5454, 'now_station': '인다마을', 'now_arrive_time': '22시', 'distance': 330.0, 'next_station': '제주대학교병원', 'next_latitude': 33.469089, 'next_longitude': 126.547389, 'hour': 15, 'weekday': 4, 'arrive_time': 63.66209904154153}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=424, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=71, timestamp=1688107600344, timestamp_type=0, key=None, value={'id': 210624, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.458783, 'now_longitude': 126.557353, 'now_station': '제대아파트', 'now_arrive_time': '22시', 'distance': 415.0, 'next_station': '제주대학교', 'next_latitude': 33.459893, 'next_longitude': 126.561624, 'hour': 15, 'weekday': 4, 'arrive_time': 50.022216651606}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=419, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=72, timestamp=1688107630961, timestamp_type=0, key=None, value={'id': 210625, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997034, 'route_nm': '360-1', 'now_latitude': 33.48486, 'now_longitude': 126.542928, 'now_station': '제주여자중고등학교(아라방면)', 'now_arrive_time': '06시', 'distance': 578.0, 'next_station': '남국원(아라방면)', 'next_latitude': 33.479705, 'next_longitude': 126.543811, 'hour': 15, 'weekday': 4, 'arrive_time': 87.17106216941892}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=484, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=73, timestamp=1688107661593, timestamp_type=0, key=None, value={'id': 210626, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997034, 'route_nm': '360-1', 'now_latitude': 33.456267, 'now_longitude': 126.55175, 'now_station': '제주대학교입구', 'now_arrive_time': '06시', 'distance': 266.0, 'next_station': '제대마을', 'next_latitude': 33.457724, 'next_longitude': 126.554014, 'hour': 15, 'weekday': 4, 'arrive_time': 40.385749410882326}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=427, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=74, timestamp=1688107692062, timestamp_type=0, key=None, value={'id': 210627, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997034, 'route_nm': '360-1', 'now_latitude': 33.457724, 'now_longitude': 126.554014, 'now_station': '제대마을', 'now_arrive_time': '06시', 'distance': 333.0, 'next_station': '제대아파트', 'next_latitude': 33.458783, 'next_longitude': 126.557353, 'hour': 15, 'weekday': 4, 'arrive_time': 46.80134154928938}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=415, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=75, timestamp=1688107722638, timestamp_type=0, key=None, value={'id': 210628, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997034, 'route_nm': '360-1', 'now_latitude': 33.458783, 'now_longitude': 126.557353, 'now_station': '제대아파트', 'now_arrive_time': '06시', 'distance': 415.0, 'next_station': '제주대학교', 'next_latitude': 33.459893, 'next_longitude': 126.561624, 'hour': 15, 'weekday': 4, 'arrive_time': 50.022216651606}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=419, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=76, timestamp=1688107753182, timestamp_type=0, key=None, value={'id': 210629, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997034, 'route_nm': '360-1', 'now_latitude': 33.479705, 'now_longitude': 126.543811, 'now_station': '남국원(아라방면)', 'now_arrive_time': '07시', 'distance': 578.0, 'next_station': '제주여자중고등학교(아라방면)', 'next_latitude': 33.48486, 'next_longitude': 126.542928, 'hour': 15, 'weekday': 4, 'arrive_time': 75.88423651711244}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=484, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=77, timestamp=1688107783753, timestamp_type=0, key=None, value={'id': 210630, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997034, 'route_nm': '360-1', 'now_latitude': 33.48486, 'now_longitude': 126.542928, 'now_station': '제주여자중고등학교(아라방면)', 'now_arrive_time': '07시', 'distance': 642.0, 'next_station': '제주중앙여자고등학교(아라방면)', 'next_latitude': 33.489414, 'next_longitude': 126.538642, 'hour': 15, 'weekday': 4, 'arrive_time': 117.15643477224096}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=527, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=78, timestamp=1688107814322, timestamp_type=0, key=None, value={'id': 210631, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997034, 'route_nm': '360-1', 'now_latitude': 33.478867, 'now_longitude': 126.483833, 'now_station': '한라중학교/부영아파트', 'now_arrive_time': '08시', 'distance': 417.0, 'next_station': '대림2차아파트', 'next_latitude': 33.47885, 'next_longitude': 126.48835, 'hour': 15, 'weekday': 4, 'arrive_time': 113.77325495259835}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=458, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=79, timestamp=1688107844849, timestamp_type=0, key=None, value={'id': 210632, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997034, 'route_nm': '360-1', 'now_latitude': 33.47885, 'now_longitude': 126.48835, 'now_station': '대림2차아파트', 'now_arrive_time': '08시', 'distance': 334.0, 'next_station': '연동대림1차아파트', 'next_latitude': 33.4807, 'next_longitude': 126.489933, 'hour': 15, 'weekday': 4, 'arrive_time': 72.68373623136941}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=443, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=80, timestamp=1688107875337, timestamp_type=0, key=None, value={'id': 210633, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997034, 'route_nm': '360-1', 'now_latitude': 33.4807, 'now_longitude': 126.489933, 'now_station': '연동대림1차아파트', 'now_arrive_time': '08시', 'distance': 550.0, 'next_station': '케이티앤지', 'next_latitude': 33.482077, 'next_longitude': 126.485355, 'hour': 15, 'weekday': 4, 'arrive_time': 125.83819610752325}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=439, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=81, timestamp=1688110436096, timestamp_type=0, key=None, value={'id': 210562, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.458783, 'now_longitude': 126.557353, 'now_station': '제대아파트', 'now_arrive_time': '15시', 'distance': 415.0, 'next_station': '제주대학교', 'next_latitude': 33.459893, 'next_longitude': 126.561624, 'hour': 14, 'weekday': 4, 'arrive_time': 55.606618677453504}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=422, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=82, timestamp=1688110467482, timestamp_type=0, key=None, value={'id': 210563, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.479705, 'now_longitude': 126.543811, 'now_station': '남국원(아라방면)', 'now_arrive_time': '17시', 'distance': 578.0, 'next_station': '제주여자중고등학교(아라방면)', 'next_latitude': 33.48486, 'next_longitude': 126.542928, 'hour': 14, 'weekday': 4, 'arrive_time': 76.34798891051614}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=484, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=83, timestamp=1688110498603, timestamp_type=0, key=None, value={'id': 210564, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.493109, 'now_longitude': 126.535091, 'now_station': '제주지방법원(아라방면)', 'now_arrive_time': '17시', 'distance': 414.0, 'next_station': '고산동산(아라방면)', 'next_latitude': 33.496007, 'next_longitude': 126.532287, 'hour': 14, 'weekday': 4, 'arrive_time': 98.11672795153949}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=473, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=84, timestamp=1688110530277, timestamp_type=0, key=None, value={'id': 210565, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.485662, 'now_longitude': 126.494923, 'now_station': '도호동', 'now_arrive_time': '17시', 'distance': 374.0, 'next_station': '은남동', 'next_latitude': 33.485822, 'next_longitude': 126.490897, 'hour': 14, 'weekday': 4, 'arrive_time': 81.7293874264768}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=396, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=85, timestamp=1688110561558, timestamp_type=0, key=None, value={'id': 210566, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.478867, 'now_longitude': 126.483833, 'now_station': '한라중학교/부영아파트', 'now_arrive_time': '18시', 'distance': 417.0, 'next_station': '대림2차아파트', 'next_latitude': 33.47885, 'next_longitude': 126.48835, 'hour': 14, 'weekday': 4, 'arrive_time': 107.96979978376271}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=458, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=86, timestamp=1688110592949, timestamp_type=0, key=None, value={'id': 210567, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.47885, 'now_longitude': 126.48835, 'now_station': '대림2차아파트', 'now_arrive_time': '18시', 'distance': 334.0, 'next_station': '연동대림1차아파트', 'next_latitude': 33.4807, 'next_longitude': 126.489933, 'hour': 14, 'weekday': 4, 'arrive_time': 72.46555105196146}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=443, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=87, timestamp=1688110624041, timestamp_type=0, key=None, value={'id': 210568, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.4807, 'now_longitude': 126.489933, 'now_station': '연동대림1차아파트', 'now_arrive_time': '18시', 'distance': 550.0, 'next_station': '케이티앤지', 'next_latitude': 33.482077, 'next_longitude': 126.485355, 'hour': 14, 'weekday': 4, 'arrive_time': 126.44634034336356}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=439, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=88, timestamp=1688110655444, timestamp_type=0, key=None, value={'id': 210569, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.482077, 'now_longitude': 126.485355, 'now_station': '케이티앤지', 'now_arrive_time': '18시', 'distance': 199.0, 'next_station': '롯데마트', 'next_latitude': 33.482142, 'next_longitude': 126.483213, 'hour': 14, 'weekday': 4, 'arrive_time': 50.384373972404255}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=416, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=89, timestamp=1688110686645, timestamp_type=0, key=None, value={'id': 210570, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.482142, 'now_longitude': 126.483213, 'now_station': '롯데마트', 'now_arrive_time': '18시', 'distance': 341.0, 'next_station': '원노형', 'next_latitude': 33.483446, 'next_longitude': 126.480758, 'hour': 14, 'weekday': 4, 'arrive_time': 72.90165676595376}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=403, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=90, timestamp=1688110717710, timestamp_type=0, key=None, value={'id': 210571, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.483446, 'now_longitude': 126.480758, 'now_station': '원노형', 'now_arrive_time': '18시', 'distance': 185.0, 'next_station': '노형오거리', 'next_latitude': 33.4858535, 'next_longitude': 126.48053, 'hour': 14, 'weekday': 4, 'arrive_time': 88.39680995900945}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=409, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=91, timestamp=1688110748826, timestamp_type=0, key=None, value={'id': 210572, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.488046, 'now_longitude': 126.483112, 'now_station': '남녕고등학교', 'now_arrive_time': '18시', 'distance': 322.0, 'next_station': '한라병원', 'next_latitude': 33.489633, 'next_longitude': 126.486, 'hour': 14, 'weekday': 4, 'arrive_time': 91.2628453455905}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=417, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=92, timestamp=1688110779815, timestamp_type=0, key=None, value={'id': 210573, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.489633, 'now_longitude': 126.486, 'now_station': '한라병원', 'now_arrive_time': '18시', 'distance': 291.0, 'next_station': '삼무공원사거리', 'next_latitude': 33.4899, 'next_longitude': 126.488917, 'hour': 14, 'weekday': 4, 'arrive_time': 91.00313695879817}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=422, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=93, timestamp=1688110810580, timestamp_type=0, key=None, value={'id': 210574, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.4899, 'now_longitude': 126.488917, 'now_station': '삼무공원사거리', 'now_arrive_time': '18시', 'distance': 381.0, 'next_station': '제원아파트', 'next_latitude': 33.487531, 'next_longitude': 126.489892, 'hour': 14, 'weekday': 4, 'arrive_time': 91.77191612920721}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=431, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=94, timestamp=1688110841263, timestamp_type=0, key=None, value={'id': 210575, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.487531, 'now_longitude': 126.489892, 'now_station': '제원아파트', 'now_arrive_time': '18시', 'distance': 267.0, 'next_station': '은남동', 'next_latitude': 33.485822, 'next_longitude': 126.490897, 'hour': 14, 'weekday': 4, 'arrive_time': 87.19015956805835}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=409, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=95, timestamp=1688110872186, timestamp_type=0, key=None, value={'id': 210576, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.485822, 'now_longitude': 126.490897, 'now_station': '은남동', 'now_arrive_time': '18시', 'distance': 374.0, 'next_station': '도호동', 'next_latitude': 33.485662, 'next_longitude': 126.494923, 'hour': 14, 'weekday': 4, 'arrive_time': 78.4733240440361}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=396, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=96, timestamp=1688111207125, timestamp_type=0, key=None, value={'id': 210582, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.500133, 'now_longitude': 126.507, 'now_station': '월구마을', 'now_arrive_time': '18시', 'distance': 375.0, 'next_station': '동성마을', 'next_latitude': 33.500045, 'next_longitude': 126.511035, 'hour': 14, 'weekday': 4, 'arrive_time': 78.06079819233892}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=406, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=97, timestamp=1688111238050, timestamp_type=0, key=None, value={'id': 210583, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.500045, 'now_longitude': 126.511035, 'now_station': '동성마을', 'now_arrive_time': '18시', 'distance': 354.0, 'next_station': '제주버스터미널', 'next_latitude': 33.49993, 'next_longitude': 126.514863, 'hour': 14, 'weekday': 4, 'arrive_time': 78.67462119279338}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=426, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=98, timestamp=1688111268889, timestamp_type=0, key=None, value={'id': 210584, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.49993, 'now_longitude': 126.514863, 'now_station': '제주버스터미널', 'now_arrive_time': '18시', 'distance': 262.0, 'next_station': '한국병원', 'next_latitude': 33.499793, 'next_longitude': 126.517687, 'hour': 14, 'weekday': 4, 'arrive_time': 77.75146572872447}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=426, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=99, timestamp=1688111299660, timestamp_type=0, key=None, value={'id': 210585, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.499789, 'now_longitude': 126.523759, 'now_station': '남서광마을', 'now_arrive_time': '18시', 'distance': 193.0, 'next_station': '탐라장애인 종합복지관', 'next_latitude': 33.500017, 'next_longitude': 126.525833, 'hour': 14, 'weekday': 4, 'arrive_time': 44.76407541293641}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=452, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=100, timestamp=1688111330327, timestamp_type=0, key=None, value={'id': 210586, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.500017, 'now_longitude': 126.525833, 'now_station': '탐라장애인 종합복지관', 'now_arrive_time': '18시', 'distance': 459.0, 'next_station': '제주시청(아라방면)', 'next_latitude': 33.49956, 'next_longitude': 126.529771, 'hour': 14, 'weekday': 4, 'arrive_time': 97.68345543995903}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=471, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=101, timestamp=1688111361162, timestamp_type=0, key=None, value={'id': 210587, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.493109, 'now_longitude': 126.535091, 'now_station': '제주지방법원(아라방면)', 'now_arrive_time': '19시', 'distance': 525.0, 'next_station': '제주중앙여자고등학교(아라방면)', 'next_latitude': 33.489414, 'next_longitude': 126.538642, 'hour': 14, 'weekday': 4, 'arrive_time': 116.73671636310347}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=510, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=102, timestamp=1688111391928, timestamp_type=0, key=None, value={'id': 210588, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.489414, 'now_longitude': 126.538642, 'now_station': '제주중앙여자고등학교(아라방면)', 'now_arrive_time': '19시', 'distance': 642.0, 'next_station': '제주여자중고등학교(아라방면)', 'next_latitude': 33.48486, 'next_longitude': 126.542928, 'hour': 14, 'weekday': 4, 'arrive_time': 87.73286311821782}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=526, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=103, timestamp=1688111422683, timestamp_type=0, key=None, value={'id': 210589, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.48486, 'now_longitude': 126.542928, 'now_station': '제주여자중고등학교(아라방면)', 'now_arrive_time': '19시', 'distance': 578.0, 'next_station': '남국원(아라방면)', 'next_latitude': 33.479705, 'next_longitude': 126.543811, 'hour': 14, 'weekday': 4, 'arrive_time': 87.69261567821447}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=484, serialized_header_size=-1)
# ====================================================================================================
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=104, timestamp=1688111453527, timestamp_type=0, key=None, value={'id': 210590, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.479705, 'now_longitude': 126.543811, 'now_station': '남국원(아라방면)', 'now_arrive_time': '19시', 'distance': 355.0, 'next_station': '아라초등학교', 'next_latitude': 33.476533, 'next_longitude': 126.544283, 'hour': 14, 'weekday': 4, 'arrive_time': 71.38001675070772}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=441, serialized_header_size=-1)
# ====================================================================================================
# ====================================================================================================
# send location data = {'id': 210458, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.458783, 'now_longitude': 126.557353, 'now_station': '제대아파트', 'now_arrive_time': '07시', 'distance': 415.0, 'next_station': '제주대학교', 'next_latitude': 33.459893, 'next_longitude': 126.561624, 'hour': 16, 'weekday': 4}
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=105, timestamp=1688111484126, timestamp_type=0, key=None, value={'id': 210591, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.476533, 'now_longitude': 126.544283, 'now_station': '아라초등학교', 'now_arrive_time': '19시', 'distance': 350.0, 'next_station': '아라주공아파트', 'next_latitude': 33.473655, 'next_longitude': 126.545425, 'hour': 14, 'weekday': 4, 'arrive_time': 74.39451555798833}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=439, serialized_header_size=-1)
# ====================================================================================================
# ====================================================================================================
# send location data = {'id': 210459, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.478867, 'now_longitude': 126.483833, 'now_station': '한라중학교/부영아파트', 'now_arrive_time': '08시', 'distance': 417.0, 'next_station': '대림2차아파트', 'next_latitude': 33.47885, 'next_longitude': 126.48835, 'hour': 16, 'weekday': 4}
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=106, timestamp=1688111514708, timestamp_type=0, key=None, value={'id': 210592, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.473655, 'now_longitude': 126.545425, 'now_station': '아라주공아파트', 'now_arrive_time': '19시', 'distance': 244.0, 'next_station': '인다마을', 'next_latitude': 33.47145, 'next_longitude': 126.5454, 'hour': 14, 'weekday': 4, 'arrive_time': 58.359269625519126}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=425, serialized_header_size=-1)
# ====================================================================================================
# ====================================================================================================
# send location data = {'id': 210460, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.47885, 'now_longitude': 126.48835, 'now_station': '대림2차아파트', 'now_arrive_time': '08시', 'distance': 334.0, 'next_station': '연동대림1차아파트', 'next_latitude': 33.4807, 'next_longitude': 126.489933, 'hour': 16, 'weekday': 4}
# get_arrive : arrive = ConsumerRecord(topic='car_arrive_topic', partition=0, offset=107, timestamp=1688111545423, timestamp_type=0, key=None, value={'id': 210593, 'date': '2019-10-29', 'route_id': 405136001, 'vh_id': 7997025, 'route_nm': '360-1', 'now_latitude': 33.47145, 'now_longitude': 126.5454, 'now_station': '인다마을', 'now_arrive_time': '19시', 'distance': 330.0, 'next_station': '제주대학교병원', 'next_latitude': 33.469089, 'next_longitude': 126.547389, 'hour': 14, 'weekday': 4, 'arrive_time': 63.879001990807815}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=425, serialized_header_size=-1)
# ====================================================================================================
